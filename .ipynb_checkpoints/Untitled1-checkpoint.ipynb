# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
Income= pd.read_csv('C:\\Users\\82102\\Desktop\\Test\\income\\1612.csv', encoding='euc-kr')
pay= pd.read_csv('C:\\Users\\82102\\Desktop\\test\\인천광역시_소비 데이터_20200630\\p1612.csv', encoding='euc-kr')

# %%
Income['']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14320 entries, 0 to 14319
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   기준년월           14320 non-null  object
#  1   행정동코드          14320 non-null  int64
#  2   시도명            14320 non-null  object
#  3   시군구명           14320 non-null  object
#  4   성별             14320 non-null  int64
#  5   연령별            14320 non-null  int64
#  6   직업구분           14320 non-null  int64
#  7   분위구분           14320 non-null  int64
#  8   평균소득           11926 non-null  float64
#  9   중위소득           11926 non-null  float64
#  10  평균처분가능소득       11926 non-null  float64
#  11  중위처분가능소득       11926 non-null  float64
#  12  소득분위배율         11816 non-null  float64
#  13  소득점유율          11926 non-null  float64
#  14  소득경계값          11926 non-null  float64
#  15  소득산출인구수        14320 non-null  int64
#  16  소득미산출인구수       14320 non-null  int64
# ...

# %%
pay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14356 entries, 0 to 14355
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   기준년월                   14356 non-null  object
#  1   행정동코드                  14356 non-null  int64
#  2   시도명                    14356 non-null  object
#  3   시군구명                   14356 non-null  object
#  4   성별                     14356 non-null  int64
#  5   연령별                    14356 non-null  int64
#  6   직업구분                   14356 non-null  int64
#  7   분위구분                   14356 non-null  int64
#  8   최근12개월신용및체크카드이용금액합계    12037 non-null  float64
#  9   최근12개월전체체크카드이용금액합계     11972 non-null  float64
#  10  최근12개월해외이용금액합계         10745 non-null  float64
#  11  최근12개월평균신용및체크카드이용금액합계  12037 non-null  float64
#  12  최근12개월평균체크카드이용금액       11972 non-null  float64
#  13  최근12개월평균해외이용금액         10745 non-null  float64
# ...

# %%
class_NB= Income['시군구명']=='남동구'
sex_NBM = Income['성별'] == 1
Income_NBM = Income[class_NB & sex_NBM]
Income_NBM
# Out:
#             기준년월       행정동코드    시도명 시군구명  성별  연령별  직업구분  분위구분    평균소득    중위소득  \
# 1     2016-12-31  2820000000  인천광역시  남동구   1   70     3     1  1307.0  1400.0
# 2     2016-12-31  2820000000  인천광역시  남동구   1   50     1     4  2338.0  2400.0
# 3     2016-12-31  2820000000  인천광역시  남동구   1   20     4     8  3372.0  3300.0
# 4     2016-12-31  2820000000  인천광역시  남동구   1    0     1     2  1812.0  1800.0
# 237   2016-12-31  2820000000  인천광역시  남동구   1   15     3     2     NaN     NaN
# ...          ...         ...    ...  ...  ..  ...   ...   ...     ...     ...
# 2587  2016-12-31  2820000000  인천광역시  남동구   1   40     3     5  2554.0  2600.0
# 2588  2016-12-31  2820000000  인천광역시  남동구   1   30     2     7  3002.0  3000.0
# 2589  2016-12-31  2820000000  인천광역시  남동구   1   20     1     9  3958.0  3900.0
# 2590  2016-12-31  2820000000  인천광역시  남동구   1    0     4     1  1446.0  1500.0
# 2604  2016-12-31  2820000000  인천광역시  남동구   1   60     2     2     NaN     NaN
#
# ...

# %%
pclass_NB= pay['시군구명']=='남동구'
psex_NBM = pay['성별'] == 1
pjob_NBM = pay['직업구분'] ==1
pc_NBM = pay['분위구분'] ==1
pay_NBM = pay[pclass_NB & psex_NBM&pjob_NBM&pc_NBM]
pay_NBM
# Out:
#             기준년월       행정동코드    시도명 시군구명  성별  연령별  직업구분  분위구분  \
# 152   2016-12-31  2820000000  인천광역시  남동구   1    0     1     1
# 171   2016-12-31  2820000000  인천광역시  남동구   1   30     1     1
# 456   2016-12-31  2820000000  인천광역시  남동구   1   50     1     1
# 499   2016-12-31  2820000000  인천광역시  남동구   1   80     1     1
# 643   2016-12-31  2820000000  인천광역시  남동구   1   15     1     1
# 665   2016-12-31  2820000000  인천광역시  남동구   1   20     1     1
# 718   2016-12-31  2820000000  인천광역시  남동구   1   40     1     1
# 771   2016-12-31  2820000000  인천광역시  남동구   1   60     1     1
# 1086  2016-12-31  2820000000  인천광역시  남동구   1   70     1     1
#
#       최근12개월신용및체크카드이용금액합계  최근12개월전체체크카드이용금액합계  ...  최근12개월해외이용인구수  \
# 152            26031119.0           2547894.0  ...            197
# 171             6008561.0            734119.0  ...             66
# 456             7648412.0            543864.0  ...             54
# 499              337464.0             29050.0  ...              2
# ...

# %%
x_NB = Income_NBM['연령별']
y_NB = Income_NBM['분위구분']
pay_NBM['직업분위'==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
groups = pay_NBM['직업분위'==1 & '소득분위'==1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8376\3392925570.py in <module>
# ----> 1 groups = pay_NBM['직업분위'==1 & '소득분위'==1]
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
