# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
F=pd.read_csv('C:\\Users\\82102\\Desktop\\Test\\income\\final1612.csv',encoding='euc-kr')
F
# Out:
#       시군구명  성별  연령  직업구분  소득분위    평균소득     평균소비  평균처분가능소득    연소득    소득대비소비  \
# 0      강화군   0   0     0     0  2789.0  11497.0    2051.0  33468  0.656478
# 1      강화군   0   0     0     1  1376.0   7528.0     458.0  16512  0.544089
# 2      강화군   0   0     0     2  1815.0   5393.0    1532.0  21780  0.752388
# 3      강화군   0   0     0     3  2062.0   6525.0    1680.0  24744  0.736300
# 4      강화군   0   0     0     4  2322.0   7753.0    1924.0  27864  0.721756
# ...    ...  ..  ..   ...   ...     ...      ...       ...    ...       ...
# 14315   중구   2  90     0     1     NaN  17408.0       NaN      0  0.000000
# 14316   중구   2  90     0     4     NaN   5869.0       NaN      0  0.000000
# 14317   중구   2  90     4     0     NaN   5894.0       NaN      0  0.000000
# 14318   중구   2  90     4     1     NaN      NaN       NaN      0  0.000000
# 14319   중구   2  90     4     4     NaN      NaN       NaN     48  1.000000
#
#          중위소득  중위처분가능소득  소득분위배율 class  Unnamed: 14  Unnamed: 15
# ...

# %%
P=pd.to_numeric(F['소득대비소비'])
F
# Out:
#       시군구명  성별  연령  직업구분  소득분위    평균소득     평균소비  평균처분가능소득    연소득    소득대비소비  \
# 0      강화군   0   0     0     0  2789.0  11497.0    2051.0  33468  0.656478
# 1      강화군   0   0     0     1  1376.0   7528.0     458.0  16512  0.544089
# 2      강화군   0   0     0     2  1815.0   5393.0    1532.0  21780  0.752388
# 3      강화군   0   0     0     3  2062.0   6525.0    1680.0  24744  0.736300
# 4      강화군   0   0     0     4  2322.0   7753.0    1924.0  27864  0.721756
# ...    ...  ..  ..   ...   ...     ...      ...       ...    ...       ...
# 14315   중구   2  90     0     1     NaN  17408.0       NaN      0  0.000000
# 14316   중구   2  90     0     4     NaN   5869.0       NaN      0  0.000000
# 14317   중구   2  90     4     0     NaN   5894.0       NaN      0  0.000000
# 14318   중구   2  90     4     1     NaN      NaN       NaN      0  0.000000
# 14319   중구   2  90     4     4     NaN      NaN       NaN     48  1.000000
#
#          중위소득  중위처분가능소득  소득분위배율 class  Unnamed: 14  Unnamed: 15
# ...

# %%
F['class']=0
F1=F[['성별','연령','직업구분','평균소득','평균소비','평균처분가능소득','소득분위','소득대비소비','class']]
F1
# Out:
#        성별  연령  직업구분    평균소득     평균소비  평균처분가능소득  소득분위    소득대비소비  class
# 0       0   0     0  2789.0  11497.0    2051.0     0  0.656478      0
# 1       0   0     0  1376.0   7528.0     458.0     1  0.544089      0
# 2       0   0     0  1815.0   5393.0    1532.0     2  0.752388      0
# 3       0   0     0  2062.0   6525.0    1680.0     3  0.736300      0
# 4       0   0     0  2322.0   7753.0    1924.0     4  0.721756      0
# ...    ..  ..   ...     ...      ...       ...   ...       ...    ...
# 14315   2  90     0     NaN  17408.0       NaN     1  0.000000      0
# 14316   2  90     0     NaN   5869.0       NaN     4  0.000000      0
# 14317   2  90     4     NaN   5894.0       NaN     0  0.000000      0
# 14318   2  90     4     NaN      NaN       NaN     1  0.000000      0
# 14319   2  90     4     NaN      NaN       NaN     4  1.000000      0
#
# [14320 rows x 9 columns]

# %%
g=F1[F1['평균처분가능소득']<0].index

# %%
F1.drop(g,inplace=True)
F1
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_14536\2949873507.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F1.drop(g,inplace=True)
#        성별  연령  직업구분    평균소득     평균소비  평균처분가능소득  소득분위    소득대비소비  class
# 0       0   0     0  2789.0  11497.0    2051.0     0  0.656478      0
# 1       0   0     0  1376.0   7528.0     458.0     1  0.544089      0
# 2       0   0     0  1815.0   5393.0    1532.0     2  0.752388      0
# 3       0   0     0  2062.0   6525.0    1680.0     3  0.736300      0
# 4       0   0     0  2322.0   7753.0    1924.0     4  0.721756      0
# ...    ..  ..   ...     ...      ...       ...   ...       ...    ...
# 14315   2  90     0     NaN  17408.0       NaN     1  0.000000      0
# 14316   2  90     0     NaN   5869.0       NaN     4  0.000000      0
# ...

# %%
F1.dropna(axis=0,inplace=True)
F1
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_14536\165174842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F1.dropna(axis=0,inplace=True)
#        성별  연령  직업구분    평균소득     평균소비  평균처분가능소득  소득분위    소득대비소비  class
# 0       0   0     0  2789.0  11497.0    2051.0     0  0.656478      0
# 1       0   0     0  1376.0   7528.0     458.0     1  0.544089      0
# 2       0   0     0  1815.0   5393.0    1532.0     2  0.752388      0
# 3       0   0     0  2062.0   6525.0    1680.0     3  0.736300      0
# 4       0   0     0  2322.0   7753.0    1924.0     4  0.721756      0
# ...    ..  ..   ...     ...      ...       ...   ...       ...    ...
# 14295   2  70     4  2728.0  12717.0    2547.0     6  0.611529      0
# 14297   2  70     4  3317.0   9793.0    1481.0     8  0.753969      0
# ...

# %%
v=F1['평균처분가능소득']

# %%
a=10000
b=6800
c=3200

# %%
def get_score(v):
    if v >a:
        score = 'A'
    elif (v <=a) & (v >b):
        score = 'B'
    elif (v <=b) & (v >c):
        score = 'C'
    else: 
        score = 'D'
    return score


F1["class"] = F1["평균처분가능소득"].apply(lambda v: get_score(v))
F1
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_14536\2201730370.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F1["class"] = F1["평균처분가능소득"].apply(lambda v: get_score(v))
#        성별  연령  직업구분    평균소득     평균소비  평균처분가능소득  소득분위    소득대비소비 class
# 0       0   0     0  2789.0  11497.0    2051.0     0  0.656478     D
# 1       0   0     0  1376.0   7528.0     458.0     1  0.544089     D
# 2       0   0     0  1815.0   5393.0    1532.0     2  0.752388     D
# 3       0   0     0  2062.0   6525.0    1680.0     3  0.736300     D
# 4       0   0     0  2322.0   7753.0    1924.0     4  0.721756     D
# ...    ..  ..   ...     ...      ...       ...   ...       ...   ...
# 14295   2  70     4  2728.0  12717.0    2547.0     6  0.611529     D
# ...

# %%
A_class_1 = F1[(F1['class']=='A') & ((F1['연령']==20) | (F1['연령']==30))]
A_1 =A_class_1.index
F1.loc[A_1,"class"]='A-1'

A_class_2 = F1[(F1['class']=='A') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
A_2 =A_class_2.index
F1.loc[A_2,"class"]='A-2'

A_class_3 = F1[(F1['class']=='A') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
A_3 =A_class_3.index
F1.loc[A_3,"class"]='A-3'

B_class_1 = F1[(F1['class']=='B') & ((F1['연령']==20) | (F1['연령']==30))]
B_1 =B_class_1.index
F1.loc[B_1,"class"]='B-1'

B_class_2 = F1[(F1['class']=='B') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
B_2 =B_class_2.index
F1.loc[B_2,"class"]='B-2'

B_class_3 = F1[(F1['class']=='B') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
B_3 =B_class_3.index
F1.loc[B_3,"class"]='B-3'

C_class_1 = F1[(F1['class']=='C') & ((F1['연령']==20) | (F1['연령']==30))]
C_1 =C_class_1.index
F1.loc[C_1,"class"]='C-1'

C_class_2 = F1[(F1['class']=='C') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
C_2 =C_class_2.index
F1.loc[C_2,"class"]='C-2'

C_class_3 = F1[(F1['class']=='C') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
C_3 =A_class_3.index
F1.loc[C_3,"class"]='C-3'

D_class_1 = F1[(F1['class']=='D') & ((F1['연령']==20) | (F1['연령']==30))]
D_1 =D_class_1.index
F1.loc[D_1,"class"]='D-1'

D_class_2 = F1[(F1['class']=='D') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
D_2 =D_class_2.index
F1.loc[D_2,"class"]='D-2'

D_class_3 = F1[(F1['class']=='D') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
D_3 =D_class_3.index
F1.loc[D_3,"class"]='D-3'

E_class_1 = F1[(F1['class']=='E') & ((F1['연령']==20) | (F1['연령']==30))]
E_1 =E_class_1.index
F1.loc[E_1,"class"]='E-1'

E_class_2 = F1[(F1['class']=='E') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
E_2 =E_class_2.index
F1.loc[E_2,"class"]='E-2'

E_class_3 = F1[(F1['class']=='E') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
E_3 =E_class_3.index
F1.loc[E_3,"class"]='E-3'

F_class_1 = F1[(F1['class']=='F') & ((F1['연령']==20) | (F1['연령']==30))]
F_1 =F_class_1.index
F1.loc[F_1,"class"]='F-1'

F_class_2 = F1[(F1['class']=='F') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
F_2 =F_class_2.index
F1.loc[F_2,"class"]='F-2'

F_class_3 = F1[(F1['class']=='F') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
F_3 =F_class_3.index
F1.loc[F_3,"class"]='F-3'

G_class_1 = F1[(F1['class']=='G') & ((F1['연령']==20) | (F1['연령']==30))]
G_1 =G_class_1.index
F1.loc[G_1,"class"]='G-1'

G_class_2 = F1[(F1['class']=='G') & ((F1['연령']==40) | (F1['연령']==50) |(F1['연령']==60))]
G_2 =G_class_2.index
F1.loc[G_2,"class"]='G-2'

G_class_3 = F1[(F1['class']=='G') & ((F1['연령']==0) | (F1['연령']==15)| (F1['연령']==70)| (F1['연령']==80)| (F1['연령']==90))]
G_3 =G_class_3.index
F1.loc[G_3,"class"]='G-3'

# %%
F1
# Out:
#        성별  연령  직업구분    평균소득     평균소비  평균처분가능소득  소득분위    소득대비소비 class
# 0       0   0     0  2789.0  11497.0    2051.0     0  0.656478   D-3
# 1       0   0     0  1376.0   7528.0     458.0     1  0.544089   D-3
# 2       0   0     0  1815.0   5393.0    1532.0     2  0.752388   D-3
# 3       0   0     0  2062.0   6525.0    1680.0     3  0.736300   D-3
# 4       0   0     0  2322.0   7753.0    1924.0     4  0.721756   D-3
# ...    ..  ..   ...     ...      ...       ...   ...       ...   ...
# 14295   2  70     4  2728.0  12717.0    2547.0     6  0.611529   D-3
# 14297   2  70     4  3317.0   9793.0    1481.0     8  0.753969   D-3
# 14298   2  70     4  4091.0  14806.0    2156.0     9  0.698403   D-3
# 14309   2  80     4  1514.0   4954.0    1250.0     0  0.727323   D-3
# 14310   2  80     4  1498.0  10138.0    1247.0     1  0.436026   D-3
#
# [10926 rows x 9 columns]

# %% [markdown]
# ##연령이랑 처분가능소득으로 했을떄
# #### F.loc[(F['연령']==20)|(F['연령']==30)&(F['평균처분가능소득']>c),'class']='A'
# #### F.loc[(F['연령']==20)|(F['연령']==30)&(F['평균처분가능소득']<=c),'class']='B'
# #### F.loc[(F['연령']==40)|(F['연령']==50)|(F['연령']==60)&(F['평균처분가능소득']>c),'class']='A'
# #### F.loc[(F['연령']==40)|(F['연령']==50)|(F['연령']==60)&(F['평균처분가능소득']<=c),'class']='C'
# #### F.loc[(F['연령']==70)|(F['연령']==80)|(F['연령']==90)&(F['평균처분가능소득']>c),'class']='B'
# #### F.loc[(F['연령']==70)|(F['연령']==80)|(F['연령']==90)&(F['평균처분가능소득']<=c),'class']='C'
# #### F.loc[(F['연령']==0)|(F['연령']==15)&(F['평균처분가능소득']>=c),'class']='B'
# #### F.loc[(F['연령']==0)|(F['연령']==15)&(F['평균처분가능소득']<=c),'class']='B'
# #### F

# %%
F1['class'][13000]
# Out:
# 'D-3'

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(F1, test_size=0.2)

#학습 데이터, 테스트 데이터 개수 확인
print(train.shape[0])
print(test.shape[0])
# Out:
# 8740
# 2186

# %%
from sklearn.neighbors import  KNeighborsClassifier
from sklearn.model_selection import cross_val_score # k-fold 교차검증

max_k_range = train.shape[0] // 2
k_list = []
for i in range(3, 101): #홀수
  k_list.append(i)

cross_validation_scores = [] # 각 k의 검증 결과 점수들
x_train = train[['소득대비소비','평균소득','평균소비','평균처분가능소득','연령']]
y_train = train[['class']]

for k in k_list:
  knn = KNeighborsClassifier(n_neighbors=k)
  scores = cross_val_score(knn, x_train, y_train.values.ravel(), cv=10,
                           scoring='accuracy')
  cross_validation_scores.append(scores.mean())

cross_validation_scores
plt.plot(k_list, cross_validation_scores)
plt.xlabel('the number of k')
plt.ylabel('Accuracy')
plt.show()
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
k = k_list[cross_validation_scores.index(max(cross_validation_scores))]
print("The best number of k : " + str(k))
# Out:
# The best number of k : 5

# %%
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=k)

x_train = train[['소득대비소비','평균소득','평균소비','연령','평균처분가능소득']]
y_train = train[['class']]

#knn 모델 학습
knn.fit(x_train, y_train.values.ravel())

x_test = test[['소득대비소비','평균소득','평균소비','연령','평균처분가능소득']]
y_test = test[['class']]

#테스트 시작
pred = knn.predict(x_test)

#모델 예측 정확도(accuracy) 출력
print("accuracy : " + str(accuracy_score(y_test.values.ravel(), pred)))
# Out:
# accuracy : 0.6052150045745655
# C:\Users\82102\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
