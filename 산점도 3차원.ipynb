# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

# %%
Final = pd.read_csv("./final1612.csv",encoding='euc-kr')

# %%
class_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   시군구명         0 non-null      object
#  1   성별           0 non-null      int64
#  2   연령           0 non-null      int64
#  3   직업구분         0 non-null      int64
#  4   소득분위         0 non-null      int64
#  5   평균소득         0 non-null      float64
#  6   평균소비         0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 0.0+ bytes

# %%
Total= Final['성별'] == 1
class_0 = Final[Total]
class_0['Z-value']=(class_0['평균소득']*12-class_0['평균소비'])/class_0['평균소득']/12
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_15648\4017889032.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   class_0['Z-value']=(class_0['평균소득']*12-class_0['평균소비'])/class_0['평균소득']/12

# %%
class_0
# Out:
#       시군구명  성별  연령  직업구분  소득분위    평균소득     평균소비  Unnamed: 7  Unnamed: 8  \
# 415    강화군   1   0     0     0  2958.0  11599.0         NaN         NaN
# 416    강화군   1   0     0     1  1365.0   7233.0         NaN         NaN
# 417    강화군   1   0     0     2  1810.0   4884.0         NaN         NaN
# 418    강화군   1   0     0     3  2060.0   6004.0         NaN         NaN
# 419    강화군   1   0     0     4  2319.0   7775.0         NaN         NaN
# ...    ...  ..  ..   ...   ...     ...      ...         ...         ...
# 13905   중구   1  80     4     5     NaN  12419.0         NaN         NaN
# 13906   중구   1  80     4     6     NaN  11574.0         NaN         NaN
# 13907   중구   1  80     4     7     NaN      NaN         NaN         NaN
# 13908   중구   1  80     4     9     NaN      NaN         NaN         NaN
# 13909   중구   1  80     4    10     NaN  18193.0         NaN         NaN
#
#        Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 415           NaN          NaN          NaN          NaN          NaN
# 416           NaN          NaN          NaN          NaN          NaN
# 417           NaN          NaN          NaN          NaN          NaN
# 418           NaN          NaN          NaN          NaN          NaN
# 419           NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 13905         NaN          NaN          NaN          NaN          NaN
# 13906         NaN          NaN          NaN          NaN          NaN
# 13907         NaN          NaN          NaN          NaN          NaN
# 13908         NaN          NaN          NaN          NaN          NaN
# 13909         NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 14    Z-value
# 415            NaN  67.323079
# 416            NaN  55.842491
# 417            NaN  77.513812
# 418            NaN  75.711974
# 419            NaN  72.060515
# ...            ...        ...
# 13905          NaN        NaN
# 13906          NaN        NaN
# 13907          NaN        NaN
# 13908          NaN        NaN
# 13909          NaN        NaN
#
# [4782 rows x 16 columns]

# %%
X_0 = class_0['연령']
Y_0 = class_0['소득분위']
Z_0 = class_0['Z-value']
X_0
# Out:
# 415       0
# 416       0
# 417       0
# 418       0
# 419       0
#          ..
# 13905    80
# 13906    80
# 13907    80
# 13908    80
# 13909    80
# Name: 연령, Length: 4782, dtype: int64

# %%
ax =plt.gca(projection = '3d')
ax.scatter(X_0,Y_0,Z_0)
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_15648\327022305.py:1: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax =plt.gca(projection = '3d')
